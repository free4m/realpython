# %%
# !python download_imdb.py
# Out:
# Fetching data from IMDb...
# Created "names.txt" and "sorted_names.txt"

# %%
def load_names(path):
    with open(path) as text_file:
        return text_file.read().splitlines()

# %%
names = load_names('names.txt')
sorted_names = load_names('sorted_names.txt')

# %%
names
# Out:
# ['Fred Astaire',
#  'Lauren Bacall',
#  'Brigitte Bardot',
#  'John Belushi',
#  'Ingmar Bergman',
#  'Ingrid Bergman',
#  'Humphrey Bogart',
#  'Marlon Brando',
#  'Richard Burton',
#  'James Cagney',
#  'Gary Cooper',
#  'Bette Davis',
#  'Doris Day',
#  'Olivia de Havilland',
#  'James Dean',
#  'Georges Delerue',
#  'Marlene Dietrich',
#  'Kirk Douglas',
#  'Federico Fellini',
#  'Henry Fonda',
#  'Joan Fontaine',
#  'Clark Gable',
#  'Judy Garland',
#  'John Gielgud',
#  'Jerry Goldsmith',
#  'Cary Grant',
#  'Alec Guinness',
#  'Rita Hayworth',
#  'Margaux Hemingway',
#  'Audrey Hepburn',
#  'Katharine Hepburn',
#  'Charlton Heston',
#  'Alfred Hitchcock',
#  'William Holden',
#  'James Horner',
#  'Buster Keaton',
#  'Gene Kelly',
#  'Grace Kelly',
#  'Deborah Kerr',
#  'Stanley Kubrick',
#  'Akira Kurosawa',
#  'Alan Ladd',
#  'Veronica Lake',
#  'Burt Lancaster',
#  'Bruce Lee',
#  'Vivien Leigh',
#  'Sophia Loren',
#  'Peter Lorre',
#  'Henry Mancini',
#  'Groucho Marx',
#  'James Mason',
#  'Marcello Mastroianni',
#  'Robert Mitchum',
#  'Marilyn Monroe',
#  'Alfred Newman',
#  'Paul Newman',
#  'David Niven',
#  "Maureen O'Hara",
#  'Laurence Olivier',
#  'Gregory Peck',
#  'Tyrone Power',
#  'Elvis Presley',
#  'Anthony Quinn',
#  'Edward G. Robinson',
#  'Nino Rota',
#  'Jane Russell',
#  'Miklós Rózsa',
#  'Randolph Scott',
#  'Frank Sinatra',
#  'Max Steiner',
#  'James Stewart',
#  'Elizabeth Taylor',
#  'Shirley Temple',
#  'Gene Tierney',
#  'Spencer Tracy',
#  'François Truffaut',
#  'Franz Waxman',
#  'John Wayne',
#  'Raquel Welch',
#  'Orson Welles',
#  'Natalie Wood',
#  'Victor Young',
#  'Alan Miller',
#  'Li Gong',
#  'Henner Hofmann',
#  'Louis de Funès',
#  'Elena Koreneva',
#  'Aleksey Korenev',
#  'Richard Paul',
#  'Armin Mueller-Stahl',
#  'Gérard Pirès',
#  'John Cleese',
#  'Brad Pitt',
#  'J. Reifel',
#  'Woody Allen',
#  'Gillian Anderson',
#  'Pamela Anderson',
#  'Jennifer Aniston',
#  'Patricia Arquette',
#  'Rowan Atkinson',
#  'Dan Aykroyd',
#  'Kevin Bacon',
#  'Fairuza Balk',
#  'Antonio Banderas',
#  'Adrienne Barbeau',
#  'Drew Barrymore',
#  'Kim Basinger',
#  'Luc Besson',
#  'Yasmine Bleeth',
#  'Kenneth Branagh',
#  'Matthew Broderick',
#  'Pierce Brosnan',
#  'Sandra Bullock',
#  'Steve Buscemi',
#  'Nicolas Cage',
#  'James Cameron',
#  'Neve Campbell',
#  'John Carpenter',
#  'Tia Carrere',
#  'Jim Carrey',
#  'Phoebe Cates',
#  'Charles Chaplin',
#  'George Clooney',
#  'Jennifer Connelly',
#  'Sean Connery',
#  'Kevin Costner',
#  'Wes Craven',
#  'Russell Crowe',
#  'Tom Cruise',
#  'Jamie Lee Curtis',
#  'John Cusack',
#  'Claire Danes',
#  'Geena Davis',
#  'Robert De Niro',
#  'John Denver',
#  'Johnny Depp',
#  'Bo Derek',
#  'Leonardo DiCaprio',
#  'Cameron Diaz',
#  'Michael Douglas',
#  'David Duchovny',
#  'Clint Eastwood',
#  'Erika Eleniak',
#  'Cary Elwes',
#  'Sherilyn Fenn',
#  'Ralph Fiennes',
#  'Colin Firth',
#  'Harrison Ford',
#  'Jodie Foster',
#  'Michael J. Fox',
#  'Morgan Freeman',
#  'Richard Gere',
#  'Gina Gershon',
#  'Mel Gibson',
#  'Whoopi Goldberg',
#  'Jeff Goldblum',
#  'Linda Hamilton',
#  'Tom Hanks',
#  'Teri Hatcher',
#  'Ethan Hawke',
#  'Salma Hayek',
#  'Anne Heche',
#  'Dustin Hoffman',
#  'Anthony Hopkins',
#  'Ron Howard',
#  'Helen Hunt',
#  'Elizabeth Hurley',
#  'Samuel L. Jackson',
#  'Tommy Lee Jones',
#  'Milla Jovovich',
#  'Ashley Judd',
#  'Harvey Keitel',
#  'Nicole Kidman',
#  'Val Kilmer',
#  'Stephen King',
#  'Nastassja Kinski',
#  'Kevin Kline',
#  'Diane Lane',
#  'Jude Law',
#  'David Lean',
#  'Heather Locklear',
#  'Jennifer Lopez',
#  'Traci Lords',
#  'George Lucas',
#  'Dolph Lundgren',
#  'David Lynch',
#  'Madonna',
#  'Steve Martin',
#  'Jenny McCarthy',
#  'Matthew McConaughey',
#  'Ewan McGregor',
#  'Alyssa Milano',
#  'Demi Moore',
#  'Julianne Moore',
#  'Bill Murray',
#  'Mike Myers',
#  'Jack Nicholson',
#  'Gary Oldman',
#  'Al Pacino',
#  'Bill Paxton',
#  'Michelle Pfeiffer',
#  'Ryan Phillippe',
#  'River Phoenix',
#  'Natalie Portman',
#  'Parker Posey',
#  'Keanu Reeves',
#  'Christina Ricci',
#  'Molly Ringwald',
#  'Tim Robbins',
#  'Julia Roberts',
#  'Mimi Rogers',
#  'Meg Ryan',
#  'Winona Ryder',
#  'Mia Sara',
#  'Susan Sarandon',
#  'Arnold Schwarzenegger',
#  'Martin Scorsese',
#  'Kristin Scott Thomas',
#  'Steven Seagal',
#  'Joan Severance',
#  'Charlie Sheen',
#  'Brooke Shields',
#  'Elisabeth Shue',
#  'Alicia Silverstone',
#  'Christian Slater',
#  'Will Smith',
#  'Mira Sorvino',
#  'Kevin Spacey',
#  'Steven Spielberg',
#  'Sylvester Stallone',
#  'Oliver Stone',
#  'Sharon Stone',
#  'Quentin Tarantino',
#  'Charlize Theron',
#  'Uma Thurman',
#  'Jennifer Tilly',
#  'John Travolta',
#  'Shannon Tweed',
#  'Liv Tyler',
#  'Skeet Ulrich',
#  'Jean-Claude Van Damme',
#  'Mark Wahlberg',
#  'Denzel Washington',
#  'Sigourney Weaver',
#  'Robin Williams',
#  'Bruce Willis',
#  'John Woo',
#  'Edward D. Wood Jr.',
#  'James Woods',
#  'Renée Zellweger',
#  'Timothy Dowling',
#  'Robert Ellis',
#  'Robert Ellis',
#  'Isabelle Adjani',
#  'Ben Affleck',
#  'Jenny Agutter',
#  'Alan Alda',
#  'Stephanie Zimbalist',
#  'Ginger Lynn',
#  'Joan Allen',
#  'Karen Allen',
#  'Nancy Allen',
#  'Kirstie Alley',
#  'Pedro Almodóvar',
#  'Robert Altman',
#  'Ursula Andress',
#  'Julie Andrews',
#  'Ann-Margret',
#  'Jean-Jacques Annaud',
#  'Gabrielle Anwar',
#  'Anne Archer',
#  'Fanny Ardant',
#  'Alan Arkin',
#  'David Arquette',
#  'Rosanna Arquette',
#  'Sean Astin',
#  'Richard Attenborough',
#  'Pernilla August',
#  'Hank Azaria',
#  'Catherine Bach',
#  'Scott Baio',
#  'Scott Bairstow',
#  'Brenda Bakke',
#  'Adam Baldwin',
#  'Alec Baldwin',
#  'Stephen Baldwin',
#  'William Baldwin',
#  'Christian Bale',
#  'Ellen Barkin',
#  'John Barry',
#  'Angela Bassett',
#  'Michelle Bauer',
#  'Sean Bean',
#  'Amanda Bearse',
#  'Kate Beckinsale',
#  'Robert Beltran',
#  'Tom Berenger',
#  'Candice Bergen',
#  'Michael Biehn',
#  'Juliette Binoche',
#  'Thora Birch',
#  'Jacqueline Bisset',
#  'Honor Blackman',
#  'Linda Blair',
#  'Mel Blanc',
#  'Brian Blessed',
#  'Helena Bonham Carter',
#  'Ernest Borgnine',
#  'David Bowie',
#  'Bruce Boxleitner',
#  'Annie Rosar',
#  'Amy Brenneman',
#  'Jeff Bridges',
#  'Charles Bronson',
#  'Louise Brooks',
#  'Mel Brooks',
#  'Clancy Brown',
#  'Tim Burton',
#  'Yancy Butler',
#  'Luis Buñuel',
#  'Gabriel Byrne',
#  'Emmanuelle Béart',
#  'Michael Caine',
#  'Barbara Carrera',
#  'David Caruso',
#  'Kim Cattrall',
#  'Lacey Chabert',
#  'Richard Chamberlain',
#  'Jackie Chan',
#  'Stockard Channing',
#  'Chevy Chase',
#  'Don Cheadle',
#  'Cher',
#  'Yun-Fat Chow',
#  'Glenn Close',
#  'James Coburn',
#  'Rachael Leigh Cook',
#  'Francis Ford Coppola',
#  'Roger Corman',
#  'Cindy Crawford',
#  'Michael Crichton',
#  'James Cromwell',
#  'David Cronenberg',
#  'Denise Crosby',
#  'Billy Crystal',
#  'Macaulay Culkin',
#  'Tim Curry',
#  'Tony Curtis',
#  'Joan Cusack',
#  "Beverly D'Angelo",
#  "Donna D'Errico",
#  "Vincent D'Onofrio",
#  'Willem Dafoe',
#  'Matt Damon',
#  'Anthony Daniels',
#  'Sybil Danning',
#  'Lolita Davidovich',
#  'Daniel Day-Lewis',
#  'Olivier De Funès',
#  'Rebecca De Mornay',
#  'Brian De Palma',
#  'Danny DeVito',
#  'Loren Dean',
#  'Sandra Dee',
#  'Julie Delpy',
#  'Catherine Deneuve',
#  'Gérard Depardieu',
#  'Laura Dern',
#  'Matt Dillon',
#  'Walt Disney',
#  'Ami Dolenz',
#  'Amanda Donohoe',
#  'Michael Dorn',
#  'Brad Dourif',
#  'Robert Downey Jr.',
#  'Fran Drescher',
#  'Richard Dreyfuss',
#  'Minnie Driver',
#  'Kirsten Dunst',
#  'Robert Duvall',
#  'Anthony Edwards',
#  'Atom Egoyan',
#  'Jennifer Ehle',
#  'Danny Elfman',
#  'Sam Elliott',
#  'Roland Emmerich',
#  'Robert Englund',
#  'R. Lee Ermey',
#  'Emilio Estevez',
#  'Joe Eszterhas',
#  'Rupert Everett',
#  'Morgan Fairchild',
#  'Peter Falk',
#  'Chris Farley',
#  'Terry Farrell',
#  'Farrah Fawcett',
#  'Corey Feldman',
#  'Sally Field',
#  'David Fincher',
#  'Linda Fiorentino',
#  'Laurence Fishburne',
#  'Carrie Fisher',
#  'Bridget Fonda',
#  'Jane Fonda',
#  'Michelle Forbes',
#  'John Ford',
#  'Vivica A. Fox',
#  'Jonathan Frakes',
#  'Brendan Fraser',
#  'Stephen Fry',
#  'Edward Furlong',
#  'Andy Garcia',
#  'Janeane Garofalo',
#  'Teri Garr',
#  'Jami Gertz',
#  'Terry Gilliam',
#  'Crispin Glover',
#  'Danny Glover',
#  'Jean-Luc Godard',
#  'Valeria Golino',
#  'Cuba Gooding Jr.',
#  'John Goodman',
#  'Serena Grandi',
#  'Hugh Grant',
#  'Peter Greenaway',
#  'Jennifer Grey',
#  'Pam Grier',
#  'D.W. Griffith',
#  'Melanie Griffith',
#  'Steve Guttenberg',
#  'Taylor Hackford',
#  'Gene Hackman',
#  'Corey Haim',
#  'Mark Hamill',
#  'Daryl Hannah',
#  'Curtis Hanson',
#  'Woody Harrelson',
#  'Ed Harris',
#  'Neil Patrick Harris',
#  'Nina Hartley',
#  'Noah Hathaway',
#  'Rutger Hauer',
#  'Goldie Hawn',
#  'Glenne Headly',
#  'Dan Hedaya',
#  'Mariel Hemingway',
#  'Marilu Henner',
#  'Lance Henriksen',
#  'Natasha Henstridge',
#  'Philip Seymour Hoffman',
#  'Gaby Hoffmann',
#  'Lauren Holly',
#  'Ian Holm',
#  'Dennis Hopper',
#  'John Hughes',
#  'Holly Hunter',
#  'John Hurt',
#  'William Hurt',
#  'Timothy Hutton',
#  'Jeremy Irons',
#  'Michael Ironside',
#  'Kate Jackson',
#  'Famke Janssen',
#  'Jim Jarmusch',
#  'Ron Jeremy',
#  'Jean-Pierre Jeunet',
#  'Don Johnson',
#  'Lynn-Holly Johnson',
#  'James Earl Jones',
#  'Jeffrey Jones',
#  'Raul Julia',
#  'Boris Karloff',
#  'Diane Keaton',
#  'Michael Keaton',
#  'Patsy Kensit',
#  'Sally Kirkland',
#  'Mia Kirshner',
#  'Tawny Kitaen',
#  'Walter Koenig',
#  'Elias Koteas',
#  'Alice Krige',
#  'Sylvia Kristel',
#  'Christopher Lambert',
#  'John Landis',
#  'Fritz Lang',
#  'Heather Langenkamp',
#  'Ang Lee',
#  'Brandon Lee',
#  'Christopher Lee',
#  'Spike Lee',
#  'John Leguizamo',
#  'Jennifer Jason Leigh',
#  'Jack Lemmon',
#  'Robert Sean Leonard',
#  'Téa Leoni',
#  'Juliette Lewis',
#  'Jennifer Lien',
#  'Matthew Lillard',
#  'Bai Ling',
#  'Richard Linklater',
#  'Ray Liotta',
#  'Christopher Lloyd',
#  'Emily Lloyd',
#  'Amy Locane',
#  'Nia Long',
#  'Julia Louis-Dreyfus',
#  'Rob Lowe',
#  'Carey Lowell',
#  'Bela Lugosi',
#  'Andie MacDowell',
#  'Shirley MacLaine',
#  'Elle Macpherson',
#  'William H. Macy',
#  'Michael Madsen',
#  'Virginia Madsen',
#  'Lee Majors',
#  'Terrence Malick',
#  'John Malkovich',
#  'David Mamet',
#  'Michael Mann',
#  'Sophie Marceau',
#  'Vanessa Marcil',
#  'Julianna Margulies',
#  'Mary Stuart Masterson',
#  'Heather Matarazzo',
#  'Samantha Mathis',
#  'Walter Matthau',
#  'Mathilda May',
#  'Debi Mazar',
#  'Andrew McCarthy',
#  'Frances McDormand',
#  'Malcolm McDowell',
#  'Gates McFadden',
#  'Kelly McGillis',
#  'Rose McGowan',
#  'Robert Duncan McNeill',
#  'Steve McQueen',
#  'Colm Meaney',
#  'Dina Meyer',
#  'Russ Meyer',
#  'Bette Midler',
#  'Penelope Ann Miller',
#  'Sal Mineo',
#  'Carmen Miranda',
#  'Helen Mirren',
#  'Matthew Modine',
#  'Alfred Molina',
#  'Elizabeth Montgomery',
#  'Roger Moore',
#  'Kate Mulgrew',
#  'Dermot Mulroney',
#  'Eddie Murphy',
#  'Liam Neeson',
#  'Sam Neill',
#  'Judd Nelson',
#  'Olivia Newton-John',
#  'Brigitte Nielsen',
#  'Leslie Nielsen',
#  'Leonard Nimoy',
#  'Nick Nolte',
#  'Peter North',
#  'Jeremy Northam',
#  "Chris O'Donnell",
#  "Peter O'Toole",
#  'Lena Olin',
#  'Julia Ormond',
#  'George Orwell',
#  'Frank Oz',
#  'Gwyneth Paltrow',
#  'Alan Parker',
#  'Mary-Louise Parker',
#  'Sarah Jessica Parker',
#  'Dolly Parton',
#  'Jason Patric',
#  'Alexandra Paul',
#  'Sean Penn',
#  'George Peppard',
#  'Anthony Perkins',
#  'Ron Perlman',
#  'Luke Perry',
#  'Joseph L. Mankiewicz',
#  'Joe Pesci',
#  'Wolfgang Petersen',
#  'Amanda Peterson',
#  'Robert Picardo',
#  'Jada Pinkett Smith',
#  'Donald Pleasence',
#  'Martha Plimpton',
#  'Eve Plumb',
#  'Edgar Allan Poe',
#  'Roman Polanski',
#  'Pete Postlethwaite',
#  'Kelly Preston',
#  'Jason Priestley',
#  'Victoria Principal',
#  'Jonathan Pryce',
#  'Bill Pullman',
#  'Dennis Quaid',
#  'Kathleen Quinlan',
#  'Sam Raimi',
#  'Harold Ramis',
#  'Robert Redford',
#  'Vanessa Redgrave',
#  'John C. Reilly',
#  'Brad Renfro',
#  'Jean Reno',
#  'Paul Reubens',
#  'Burt Reynolds',
#  'Ving Rhames',
#  'Giovanni Ribisi',
#  'Ariana Richards',
#  'Denise Richards',
#  'Joely Richardson',
#  'Alan Rickman',
#  'John Ritter',
#  'Eric Roberts',
#  'Tanya Roberts',
#  'Isabella Rossellini',
#  'Tim Roth',
#  'Mickey Rourke',
#  'Kurt Russell',
#  'Theresa Russell',
#  'Rene Russo',
#  'Laura San Giacomo',
#  'Fred Savage',
#  'John Sayles',
#  'Greta Scacchi',
#  'Johnathon Schaech',
#  'Claudia Schiffer',
#  'Liev Schreiber',
#  'Ridley Scott',
#  'Jerry Seinfeld',
#  'Tom Selleck',
#  'Peter Sellers',
#  'Yahoo Serious',
#  'William Shakespeare',
#  'Tupac Shakur',
#  'William Shatner',
#  'Ally Sheedy',
#  'Martin Sheen',
#  'Gary Sinise',
#  'Marina Sirtis',
#  'Tom Skerritt',
#  'Helen Slater',
#  'Anna Nicole Smith',
#  'Jaclyn Smith',
#  'Alan Smithee',
#  'Wesley Snipes',
#  'Paul Sorvino',
#  'Talisa Soto',
#  'Sissy Spacek',
#  'James Spader',
#  'Brent Spiner',
#  'Terence Stamp',
#  'Eric Stoltz',
#  'Madeleine Stowe',
#  'David Strathairn',
#  'Meryl Streep',
#  'Barbra Streisand',
#  'Tami Stronach',
#  'Donald Sutherland',
#  'Kiefer Sutherland',
#  'Dominique Swain',
#  'Patrick Swayze',
#  'D.B. Sweeney',
#  'Lili Taylor',
#  'David Thewlis',
#  'Emma Thompson',
#  'Fred Dalton Thompson',
#  'Lea Thompson',
#  'Billy Bob Thornton',
#  'Meg Tilly',
#  'Marisa Tomei',
#  'Tamlyn Tomita',
#  'Jeanne Tripplehorn',
#  'Chris Tucker',
#  'Robin Tunney',
#  'Kathleen Turner',
#  'Deborah Kara Unger',
#  'Casper Van Dien',
#  'Vince Vaughn',
#  'Paul Verhoeven',
#  'Gore Vidal',
#  'Nana Visitor',
#  'Jon Voight',
#  'Christopher Walken',
#  'J.T. Walsh',
#  'Sela Ward',
#  'Julie Warner',
#  'Lesley Ann Warren',
#  'John Waters',
#  'Teri Weigel',
#  'Peter Weller',
#  'Wim Wenders',
#  'Joanne Whalley',
#  'Wil Wheaton',
#  'Billy Wilder',
#  'Gene Wilder',
#  'Michael Wincott',
#  'Debra Winger',
#  'Kate Winslet',
#  'Reese Witherspoon',
#  'BD Wong',
#  'Elijah Wood',
#  'Robin Wright',
#  'Michelle Yeoh',
#  'Sean Young',
#  'Billy Zane',
#  'Robert Zemeckis',
#  'David Raksin',
#  'Rick Baker',
#  'Steve Cohen',
#  'Joel Oliansky',
#  'Willie Aames',
#  'Caroline Aaron',
#  'Paula Abdul',
#  'Kareem Abdul-Jabbar',
#  'Ian Abercrombie',
#  'F. Murray Abraham',
#  'Jim Abrahams',
#  'Victoria Abril',
#  'Joss Ackland',
#  'Deborah Adair',
#  'Brooke Adams',
#  'Joey Lauren Adams',
#  'Maud Adams',
#  'Percy Adlon',
#  'Mario Adorf',
#  'Casey Affleck',
#  'John Agar',
#  'Brian Aherne',
#  'Danny Aiello',
#  'Anouk Aimée',
#  'Eddie Albert',
#  'Brian Aldiss',
#  'Robert Aldrich',
#  'Jane Alexander',
#  'Muhammad Ali',
#  'Debbie Allen',
#  'Irwin Allen',
#  'Tim Allen',
#  'June Allyson',
#  'Néstor Almendros',
#  'Maria Conchita Alonso',
#  'Carol Alt',
#  'Trini Alvarado',
#  'Don Ameche',
#  'Leon Ames',
#  'Mädchen Amick',
#  'Jon Amiel',
#  'Suzy Amis',
#  'Judith Anderson',
#  'Juliet Anderson',
#  'Kevin Anderson',
#  'Lindsay Anderson',
#  'Loni Anderson',
#  'Melissa Sue Anderson',
#  'Melody Anderson',
#  'Paul Thomas Anderson',
#  'Richard Dean Anderson',
#  'Bibi Andersson',
#  'Anthony Andrews',
#  'Dana Andrews',
#  'André the Giant',
#  'Pier Angeli',
#  'Theodoros Angelopoulos',
#  'Jean-Hugues Anglade',
#  'Francesca Annis',
#  'Susan Anspach',
#  'David Anspaugh',
#  'Lysette Anthony',
#  'Susan Anton',
#  'Laura Antonelli',
#  'Michelangelo Antonioni',
#  'Christina Applegate',
#  'Michael Apted',
#  'Gregg Araki',
#  'Alfonso Arau',
#  "Roscoe 'Fatty' Arbuckle",
#  'Denys Arcand',
#  'Eve Arden',
#  'Asia Argento',
#  'Dario Argento',
#  'Pedro Armendáriz',
#  'Alison Armitage',
#  'George Armitage',
#  'Bess Armstrong',
#  'Gillian Armstrong',
#  'Desi Arnaz',
#  'James Arness',
#  'Jack Arnold',
#  'Tom Arnold',
#  'Alexis Arquette',
#  'Lewis Arquette',
#  'Jean Arthur',
#  'Dana Ashbrook',
#  'Hal Ashby',
#  'Linden Ashby',
#  'Edward Asner',
#  'Armand Assante',
#  'Olivier Assayas',
#  'Mary Astor',
#  'Christopher Atkins',
#  'Stéphane Audran',
#  'Claudine Auger',
#  'Bille August',
#  'Jane Austen',
#  'Paul Auster',
#  'Daniel Auteuil',
#  'Gene Autry',
#  'Frankie Avalon',
#  'Roger Avary',
#  'Tex Avery',
#  'John G. Avildsen',
#  'Mili Avital',
#  'Jon Avnet',
#  'Lew Ayres',
#  'Shabana Azmi',
#  'Barbara Bach',
#  'Burt Bacharach',
#  'Amitabh Bachchan',
#  'Jim Backus',
#  'Angelo Badalamenti',
#  'John Badham',
#  'Mary Badham',
#  'Jane Badler',
#  'Maxine Bahns',
#  'Barbara Bain',
#  'Stuart Baird',
#  'Oksana Baiul',
#  'Diane Baker',
#  'Joe Don Baker',
#  'Kathy Baker',
#  'Ralph Bakshi',
#  'Scott Bakula',
#  'Bob Balaban',
#  'Daniel Baldwin',
#  'Ina Balin',
#  'Lucille Ball',
#  'Michael Ballhaus',
#  'Martin Balsam',
#  'Anne Bancroft',
#  'Tamasaburô Bandô',
#  'Tallulah Bankhead',
#  'Ian Bannen',
#  'Theda Bara',
#  'Olivia Barash',
#  'Javier Bardem',
#  'Clive Barker',
#  'Lex Barker',
#  'Jean-Marc Barr',
#  'Bruno Barreto',
#  'Majel Barrett',
#  'Raymond J. Barry',
#  'Ethel Barrymore',
#  'John Drew Barrymore',
#  'John Barrymore',
#  'Lionel Barrymore',
#  'Paul Bartel',
#  'Freddie Bartholomew',
#  'Robin Bartlett',
#  'Billy Barty',
#  'Mikhail Baryshnikov',
#  'Richard Basehart',
#  'Saul Bass',
#  'Jason Bateman',
#  'Justine Bateman',
#  'Alan Bates',
#  'Kathy Bates',
#  'Randall Batinkoff',
#  'Patrick Bauchau',
#  'Belinda Bauer',
#  'Steven Bauer',
#  'L. Frank Baum',
#  'Noah Baumbach',
#  'Lamberto Bava',
#  'Mario Bava',
#  'Anne Baxter',
#  'Meredith Baxter',
#  'Michael Bay',
#  'Nathalie Baye',
#  'Stephanie Beacham',
#  'Jennifer Beals',
#  'Ned Beatty',
#  'Warren Beatty',
#  'Harold Becker',
#  'Meret Becker',
#  'Bonnie Bedelia',
#  'Noah Beery Jr.',
#  'Wallace Beery',
#  'Jason Beghe',
#  'Ed Begley Jr.',
#  'Jean-Jacques Beineix',
#  'Barbara Bel Geddes',
#  'Harry Belafonte',
#  'Ralph Bellamy',
#  'Kathleen Beller',
#  'Monica Bellucci',
#  'Pamela Bellwood',
#  'Jean-Paul Belmondo',
#  'Jim Belushi',
#  'Brian Benben',
#  'William Bendix',
#  'Roberto Benigni',
#  'Annette Bening',
#  'Richard Benjamin',
#  'David Bennent',
#  'Constance Bennett',
#  'Joan Bennett',
#  'Nigel Bennett',
#  'Jack Benny',
#  'Robby Benson',
#  'Robert Benton',
#  'Bruce Beresford',
#  'Peter Berg',
#  'Polly Bergen',
#  'Helmut Berger',
#  'Senta Berger',
#  'Patrick Bergin',
#  'Andrew Bergman',
#  'Sandahl Bergman',
#  'Busby Berkeley',
#  'Elizabeth Berkley',
#  'Steven Berkoff',
#  'Milton Berle',
#  'Irving Berlin',
#  'Sandra Bernhard',
#  'Corbin Bernsen',
#  'Elmer Bernstein',
#  'Elizabeth Berridge',
#  'Halle Berry',
#  'Valerie Bertinelli',
#  'Bernardo Bertolucci',
#  'Bibi Besch',
#  'Martine Beswick',
#  'Richard Beymer',
#  'Daniela Bianchi',
#  'Adrian Biddle',
#  'Bigas Luna',
#  'Kathryn Bigelow',
#  'Theodore Bikel',
#  'Traci Bingham',
#  'Antonia Bird',
#  'Jane Birkin',
#  'Whit Bissell',
#  'Karen Black',
#  'Shane Black',
#  'Cate Blanchett',
#  'Brenda Blethyn',
#  'Joan Blondell',
#  'Hart Bochner',
#  'Peter Bogdanovich',
#  'Jon Bon Jovi',
#  'Ward Bond',
#  'Lisa Bonet',
#  'Jan de Bont',
#  'John Boorman',
#  'Powers Boothe',
#  'Barry Bostwick',
#  'Timothy Bottoms',
#  'Carole Bouquet',
#  'Stephen Boyd',
#  'Charles Boyer',
#  'Danny Boyle',
#  'Lorraine Bracco',
#  'Eric Braeden',
#  'Sônia Braga',
#  'Lillo Brancato',
#  'Jonathan Brandis',
#  'Nicoletta Braschi',
#  'Tinto Brass',
#  'Benjamin Bratt',
#  'Walter Brennan',
#  'Robert Bresson',
#  'Martin Brest',
#  'Beau Bridges',
#  'Lloyd Bridges',
#  'Wilford Brimley',
#  'Jim Broadbent',
#  'James Brolin',
#  'Josh Brolin',
#  'Albert Brooks',
#  'Avery Brooks',
#  'James L. Brooks',
#  'Bryan Brown',
#  'Jim Brown',
#  'Jerry Bruckheimer',
#  'Yul Brynner',
#  'Betty Buckley',
#  'Geneviève Bujold',
#  'Billie Burke',
#  'Carol Burnett',
#  'Raymond Burr',
#  'Ellen Burstyn',
#  'LeVar Burton',
#  'Gary Busey',
#  'Jake Busey',
#  'Red Buttons',
#  'Tom Byron',
#  'James Caan',
#  ...]

# %%
import random

def find(elements, value):
    while True:
        random_element = random.choice(elements)
        if random_element == value:
            return random_element

# %%
# linear search
def find_index(elements, value):
    for index, element in enumerate(elements):
        if element == value:
            return index

# %%
# %%time
i = find_index(names, 'Alicia Monica')
i
# Out:
# CPU times: user 243 ms, sys: 1.72 ms, total: 245 ms
# Wall time: 244 ms
# 4969883

# %%
from benchmark import load_names

names = load_names('names.txt')
index_by_name = {name: index for index, name in enumerate(names)}
# Out:
# Loading names...ok

# %%
index_by_name
# Out:
# {'Fred Astaire': 0,
#  'Lauren Bacall': 1,
#  'Brigitte Bardot': 2,
#  'John Belushi': 3,
#  'Ingmar Bergman': 4,
#  'Ingrid Bergman': 9924286,
#  'Humphrey Bogart': 6,
#  'Marlon Brando': 7,
#  'Richard Burton': 9419343,
#  'James Cagney': 9,
#  'Gary Cooper': 9669441,
#  'Bette Davis': 10054596,
#  'Doris Day': 6975118,
#  'Olivia de Havilland': 13,
#  'James Dean': 9964499,
#  'Georges Delerue': 15,
#  'Marlene Dietrich': 1594767,
#  'Kirk Douglas': 7640512,
#  'Federico Fellini': 18,
#  'Henry Fonda': 19,
#  'Joan Fontaine': 4493301,
#  'Clark Gable': 6788949,
#  'Judy Garland': 22,
#  'John Gielgud': 9724140,
#  'Jerry Goldsmith': 24,
#  'Cary Grant': 8637194,
#  'Alec Guinness': 26,
#  'Rita Hayworth': 27,
#  'Margaux Hemingway': 28,
#  'Audrey Hepburn': 9390290,
#  'Katharine Hepburn': 30,
#  'Charlton Heston': 31,
#  'Alfred Hitchcock': 3704870,
#  'William Holden': 9687424,
#  'James Horner': 9974629,
#  'Buster Keaton': 7972764,
#  'Gene Kelly': 6946130,
#  'Grace Kelly': 9964627,
#  'Deborah Kerr': 8938914,
#  'Stanley Kubrick': 39,
#  'Akira Kurosawa': 40,
#  'Alan Ladd': 455223,
#  'Veronica Lake': 7569062,
#  'Burt Lancaster': 43,
#  'Bruce Lee': 9260298,
#  'Vivien Leigh': 8669247,
#  'Sophia Loren': 46,
#  'Peter Lorre': 493452,
#  'Henry Mancini': 48,
#  'Groucho Marx': 49,
#  'James Mason': 9755838,
#  'Marcello Mastroianni': 51,
#  'Robert Mitchum': 7927232,
#  'Marilyn Monroe': 53,
#  'Alfred Newman': 54,
#  'Paul Newman': 9382470,
#  'David Niven': 5837653,
#  "Maureen O'Hara": 7878465,
#  'Laurence Olivier': 1346770,
#  'Gregory Peck': 59,
#  'Tyrone Power': 60,
#  'Elvis Presley': 61,
#  'Anthony Quinn': 8278581,
#  'Edward G. Robinson': 4341220,
#  'Nino Rota': 8734749,
#  'Jane Russell': 6656885,
#  'Miklós Rózsa': 3894409,
#  'Randolph Scott': 9568873,
#  'Frank Sinatra': 68,
#  'Max Steiner': 7959596,
#  'James Stewart': 10064538,
#  'Elizabeth Taylor': 9031775,
#  'Shirley Temple': 72,
#  'Gene Tierney': 73,
#  'Spencer Tracy': 5012571,
#  'François Truffaut': 75,
#  'Franz Waxman': 76,
#  'John Wayne': 9371178,
#  'Raquel Welch': 78,
#  'Orson Welles': 79,
#  'Natalie Wood': 9612788,
#  'Victor Young': 9587656,
#  'Alan Miller': 9045229,
#  'Li Gong': 83,
#  'Henner Hofmann': 84,
#  'Louis de Funès': 85,
#  'Elena Koreneva': 86,
#  'Aleksey Korenev': 87,
#  'Richard Paul': 9503413,
#  'Armin Mueller-Stahl': 89,
#  'Gérard Pirès': 90,
#  'John Cleese': 91,
#  'Brad Pitt': 92,
#  'J. Reifel': 93,
#  'Woody Allen': 94,
#  'Gillian Anderson': 6341044,
#  'Pamela Anderson': 9857657,
#  'Jennifer Aniston': 97,
#  'Patricia Arquette': 98,
#  'Rowan Atkinson': 99,
#  'Dan Aykroyd': 100,
#  'Kevin Bacon': 9885392,
#  'Fairuza Balk': 102,
#  'Antonio Banderas': 103,
#  'Adrienne Barbeau': 104,
#  'Drew Barrymore': 8073580,
#  'Kim Basinger': 106,
#  'Luc Besson': 107,
#  'Yasmine Bleeth': 108,
#  'Kenneth Branagh': 109,
#  'Matthew Broderick': 4695313,
#  'Pierce Brosnan': 111,
#  'Sandra Bullock': 112,
#  'Steve Buscemi': 113,
#  'Nicolas Cage': 114,
#  'James Cameron': 9887623,
#  'Neve Campbell': 116,
#  'John Carpenter': 9167852,
#  'Tia Carrere': 118,
#  'Jim Carrey': 1548613,
#  'Phoebe Cates': 120,
#  'Charles Chaplin': 121,
#  'George Clooney': 122,
#  'Jennifer Connelly': 9444084,
#  'Sean Connery': 124,
#  'Kevin Costner': 125,
#  'Wes Craven': 126,
#  'Russell Crowe': 127,
#  'Tom Cruise': 128,
#  'Jamie Lee Curtis': 129,
#  'John Cusack': 7804056,
#  'Claire Danes': 131,
#  'Geena Davis': 132,
#  'Robert De Niro': 133,
#  'John Denver': 9424689,
#  'Johnny Depp': 135,
#  'Bo Derek': 1802426,
#  'Leonardo DiCaprio': 137,
#  'Cameron Diaz': 138,
#  'Michael Douglas': 10060758,
#  'David Duchovny': 140,
#  'Clint Eastwood': 141,
#  'Erika Eleniak': 142,
#  'Cary Elwes': 143,
#  'Sherilyn Fenn': 144,
#  'Ralph Fiennes': 145,
#  'Colin Firth': 146,
#  'Harrison Ford': 9655704,
#  'Jodie Foster': 148,
#  'Michael J. Fox': 6792801,
#  'Morgan Freeman': 7396954,
#  'Richard Gere': 151,
#  'Gina Gershon': 152,
#  'Mel Gibson': 3927998,
#  'Whoopi Goldberg': 154,
#  'Jeff Goldblum': 155,
#  'Linda Hamilton': 9225797,
#  'Tom Hanks': 157,
#  'Teri Hatcher': 158,
#  'Ethan Hawke': 159,
#  'Salma Hayek': 160,
#  'Anne Heche': 161,
#  'Dustin Hoffman': 162,
#  'Anthony Hopkins': 10002143,
#  'Ron Howard': 9968376,
#  'Helen Hunt': 9697056,
#  'Elizabeth Hurley': 6828782,
#  'Samuel L. Jackson': 167,
#  'Tommy Lee Jones': 168,
#  'Milla Jovovich': 169,
#  'Ashley Judd': 7813136,
#  'Harvey Keitel': 171,
#  'Nicole Kidman': 172,
#  'Val Kilmer': 173,
#  'Stephen King': 8534806,
#  'Nastassja Kinski': 175,
#  'Kevin Kline': 4415844,
#  'Diane Lane': 459811,
#  'Jude Law': 1242164,
#  'David Lean': 9763207,
#  'Heather Locklear': 180,
#  'Jennifer Lopez': 8666554,
#  'Traci Lords': 182,
#  'George Lucas': 5998923,
#  'Dolph Lundgren': 184,
#  'David Lynch': 9502243,
#  'Madonna': 9131562,
#  'Steve Martin': 10062265,
#  'Jenny McCarthy': 9685702,
#  'Matthew McConaughey': 189,
#  'Ewan McGregor': 190,
#  'Alyssa Milano': 191,
#  'Demi Moore': 192,
#  'Julianne Moore': 193,
#  'Bill Murray': 8602017,
#  'Mike Myers': 9631008,
#  'Jack Nicholson': 8226161,
#  'Gary Oldman': 197,
#  'Al Pacino': 7528263,
#  'Bill Paxton': 199,
#  'Michelle Pfeiffer': 200,
#  'Ryan Phillippe': 201,
#  'River Phoenix': 202,
#  'Natalie Portman': 203,
#  'Parker Posey': 204,
#  'Keanu Reeves': 205,
#  'Christina Ricci': 6113510,
#  'Molly Ringwald': 207,
#  'Tim Robbins': 8403216,
#  'Julia Roberts': 10048694,
#  'Mimi Rogers': 4053316,
#  'Meg Ryan': 9733661,
#  'Winona Ryder': 212,
#  'Mia Sara': 213,
#  'Susan Sarandon': 214,
#  'Arnold Schwarzenegger': 215,
#  'Martin Scorsese': 216,
#  'Kristin Scott Thomas': 217,
#  'Steven Seagal': 218,
#  'Joan Severance': 219,
#  'Charlie Sheen': 220,
#  'Brooke Shields': 221,
#  'Elisabeth Shue': 222,
#  'Alicia Silverstone': 223,
#  'Christian Slater': 9380342,
#  'Will Smith': 9973251,
#  'Mira Sorvino': 226,
#  'Kevin Spacey': 227,
#  'Steven Spielberg': 228,
#  'Sylvester Stallone': 229,
#  'Oliver Stone': 9819337,
#  'Sharon Stone': 9943698,
#  'Quentin Tarantino': 232,
#  'Charlize Theron': 233,
#  'Uma Thurman': 234,
#  'Jennifer Tilly': 235,
#  'John Travolta': 7087239,
#  'Shannon Tweed': 7199063,
#  'Liv Tyler': 238,
#  'Skeet Ulrich': 239,
#  'Jean-Claude Van Damme': 240,
#  'Mark Wahlberg': 6804541,
#  'Denzel Washington': 242,
#  'Sigourney Weaver': 1628517,
#  'Robin Williams': 9885911,
#  'Bruce Willis': 245,
#  'John Woo': 10013689,
#  'Edward D. Wood Jr.': 5813462,
#  'James Woods': 9770499,
#  'Renée Zellweger': 249,
#  'Timothy Dowling': 4663740,
#  'Robert Ellis': 9840800,
#  'Isabelle Adjani': 253,
#  'Ben Affleck': 254,
#  'Jenny Agutter': 255,
#  'Alan Alda': 256,
#  'Stephanie Zimbalist': 257,
#  'Ginger Lynn': 1910261,
#  'Joan Allen': 9893816,
#  'Karen Allen': 8120950,
#  'Nancy Allen': 8751158,
#  'Kirstie Alley': 262,
#  'Pedro Almodóvar': 263,
#  'Robert Altman': 9455851,
#  'Ursula Andress': 265,
#  'Julie Andrews': 6913973,
#  'Ann-Margret': 267,
#  'Jean-Jacques Annaud': 268,
#  'Gabrielle Anwar': 269,
#  'Anne Archer': 7188793,
#  'Fanny Ardant': 271,
#  'Alan Arkin': 272,
#  'David Arquette': 273,
#  'Rosanna Arquette': 274,
#  'Sean Astin': 275,
#  'Richard Attenborough': 276,
#  'Pernilla August': 277,
#  'Hank Azaria': 278,
#  'Catherine Bach': 8133028,
#  'Scott Baio': 280,
#  'Scott Bairstow': 281,
#  'Brenda Bakke': 282,
#  'Adam Baldwin': 8760237,
#  'Alec Baldwin': 8776298,
#  'Stephen Baldwin': 6957936,
#  'William Baldwin': 9290526,
#  'Christian Bale': 287,
#  'Ellen Barkin': 288,
#  'John Barry': 9490315,
#  'Angela Bassett': 290,
#  'Michelle Bauer': 291,
#  'Sean Bean': 292,
#  'Amanda Bearse': 293,
#  'Kate Beckinsale': 294,
#  'Robert Beltran': 8377194,
#  'Tom Berenger': 296,
#  'Candice Bergen': 2105712,
#  'Michael Biehn': 298,
#  'Juliette Binoche': 299,
#  'Thora Birch': 300,
#  'Jacqueline Bisset': 301,
#  'Honor Blackman': 302,
#  'Linda Blair': 7605072,
#  'Mel Blanc': 304,
#  'Brian Blessed': 305,
#  'Helena Bonham Carter': 306,
#  'Ernest Borgnine': 307,
#  'David Bowie': 8453140,
#  'Bruce Boxleitner': 309,
#  'Annie Rosar': 310,
#  'Amy Brenneman': 5317923,
#  'Jeff Bridges': 7925219,
#  'Charles Bronson': 8233605,
#  'Louise Brooks': 9854893,
#  'Mel Brooks': 315,
#  'Clancy Brown': 9805743,
#  'Tim Burton': 9026654,
#  'Yancy Butler': 318,
#  'Luis Buñuel': 319,
#  'Gabriel Byrne': 320,
#  'Emmanuelle Béart': 321,
#  'Michael Caine': 7833913,
#  'Barbara Carrera': 3068072,
#  'David Caruso': 8345899,
#  'Kim Cattrall': 325,
#  'Lacey Chabert': 326,
#  'Richard Chamberlain': 8888924,
#  'Jackie Chan': 9674080,
#  'Stockard Channing': 329,
#  'Chevy Chase': 10040290,
#  'Don Cheadle': 331,
#  'Cher': 2776985,
#  'Yun-Fat Chow': 333,
#  'Glenn Close': 334,
#  'James Coburn': 9746484,
#  'Rachael Leigh Cook': 336,
#  'Francis Ford Coppola': 337,
#  'Roger Corman': 338,
#  'Cindy Crawford': 4056302,
#  'Michael Crichton': 340,
#  'James Cromwell': 7357907,
#  'David Cronenberg': 342,
#  'Denise Crosby': 6928594,
#  'Billy Crystal': 344,
#  'Macaulay Culkin': 345,
#  'Tim Curry': 6665315,
#  'Tony Curtis': 9683221,
#  'Joan Cusack': 348,
#  "Beverly D'Angelo": 6654461,
#  "Donna D'Errico": 3847739,
#  "Vincent D'Onofrio": 351,
#  'Willem Dafoe': 352,
#  'Matt Damon': 353,
#  'Anthony Daniels': 8954969,
#  'Sybil Danning': 355,
#  'Lolita Davidovich': 356,
#  'Daniel Day-Lewis': 357,
#  'Olivier De Funès': 358,
#  'Rebecca De Mornay': 359,
#  'Brian De Palma': 360,
#  'Danny DeVito': 361,
#  'Loren Dean': 362,
#  'Sandra Dee': 9953916,
#  'Julie Delpy': 364,
#  'Catherine Deneuve': 365,
#  'Gérard Depardieu': 366,
#  'Laura Dern': 367,
#  'Matt Dillon': 9886711,
#  'Walt Disney': 369,
#  'Ami Dolenz': 370,
#  'Amanda Donohoe': 371,
#  'Michael Dorn': 7247857,
#  'Brad Dourif': 373,
#  'Robert Downey Jr.': 374,
#  'Fran Drescher': 375,
#  'Richard Dreyfuss': 376,
#  'Minnie Driver': 377,
#  'Kirsten Dunst': 378,
#  'Robert Duvall': 1548443,
#  'Anthony Edwards': 9900443,
#  'Atom Egoyan': 381,
#  'Jennifer Ehle': 382,
#  'Danny Elfman': 383,
#  'Sam Elliott': 9269536,
#  'Roland Emmerich': 385,
#  'Robert Englund': 386,
#  'R. Lee Ermey': 387,
#  'Emilio Estevez': 388,
#  'Joe Eszterhas': 389,
#  'Rupert Everett': 390,
#  'Morgan Fairchild': 391,
#  'Peter Falk': 7292345,
#  'Chris Farley': 10056246,
#  'Terry Farrell': 7097650,
#  'Farrah Fawcett': 395,
#  'Corey Feldman': 396,
#  'Sally Field': 2417247,
#  'David Fincher': 398,
#  'Linda Fiorentino': 1088338,
#  'Laurence Fishburne': 400,
#  'Carrie Fisher': 9111532,
#  'Bridget Fonda': 402,
#  'Jane Fonda': 403,
#  'Michelle Forbes': 8250982,
#  'John Ford': 10003403,
#  'Vivica A. Fox': 406,
#  'Jonathan Frakes': 407,
#  'Brendan Fraser': 408,
#  'Stephen Fry': 10015053,
#  'Edward Furlong': 410,
#  'Andy Garcia': 10006051,
#  'Janeane Garofalo': 412,
#  'Teri Garr': 413,
#  'Jami Gertz': 414,
#  'Terry Gilliam': 415,
#  'Crispin Glover': 416,
#  'Danny Glover': 417,
#  'Jean-Luc Godard': 418,
#  'Valeria Golino': 419,
#  'Cuba Gooding Jr.': 420,
#  'John Goodman': 9011561,
#  'Serena Grandi': 422,
#  'Hugh Grant': 7808003,
#  'Peter Greenaway': 424,
#  'Jennifer Grey': 9396964,
#  'Pam Grier': 426,
#  'D.W. Griffith': 4911612,
#  'Melanie Griffith': 8056517,
#  'Steve Guttenberg': 8984269,
#  'Taylor Hackford': 430,
#  'Gene Hackman': 431,
#  'Corey Haim': 432,
#  'Mark Hamill': 8630132,
#  'Daryl Hannah': 434,
#  'Curtis Hanson': 435,
#  'Woody Harrelson': 436,
#  'Ed Harris': 8345840,
#  'Neil Patrick Harris': 438,
#  'Nina Hartley': 439,
#  'Noah Hathaway': 440,
#  'Rutger Hauer': 441,
#  'Goldie Hawn': 442,
#  'Glenne Headly': 443,
#  'Dan Hedaya': 444,
#  'Mariel Hemingway': 445,
#  'Marilu Henner': 446,
#  'Lance Henriksen': 447,
#  'Natasha Henstridge': 448,
#  'Philip Seymour Hoffman': 449,
#  'Gaby Hoffmann': 8495299,
#  'Lauren Holly': 451,
#  'Ian Holm': 452,
#  'Dennis Hopper': 453,
#  'John Hughes': 9855410,
#  'Holly Hunter': 10037458,
#  'John Hurt': 456,
#  'William Hurt': 457,
#  'Timothy Hutton': 458,
#  'Jeremy Irons': 459,
#  'Michael Ironside': 460,
#  'Kate Jackson': 9951421,
#  'Famke Janssen': 462,
#  'Jim Jarmusch': 463,
#  'Ron Jeremy': 464,
#  'Jean-Pierre Jeunet': 465,
#  'Don Johnson': 9873053,
#  'Lynn-Holly Johnson': 467,
#  'James Earl Jones': 468,
#  'Jeffrey Jones': 9220065,
#  'Raul Julia': 470,
#  'Boris Karloff': 7211766,
#  'Diane Keaton': 472,
#  'Michael Keaton': 473,
#  'Patsy Kensit': 474,
#  'Sally Kirkland': 6994173,
#  'Mia Kirshner': 476,
#  'Tawny Kitaen': 477,
#  'Walter Koenig': 4177321,
#  'Elias Koteas': 479,
#  'Alice Krige': 480,
#  'Sylvia Kristel': 481,
#  'Christopher Lambert': 9648846,
#  'John Landis': 6744619,
#  'Fritz Lang': 7338403,
#  'Heather Langenkamp': 485,
#  'Ang Lee': 8977695,
#  'Brandon Lee': 9897506,
#  'Christopher Lee': 10050860,
#  'Spike Lee': 489,
#  'John Leguizamo': 490,
#  'Jennifer Jason Leigh': 491,
#  'Jack Lemmon': 492,
#  'Robert Sean Leonard': 493,
#  'Téa Leoni': 494,
#  'Juliette Lewis': 9328770,
#  'Jennifer Lien': 496,
#  'Matthew Lillard': 497,
#  'Bai Ling': 498,
#  'Richard Linklater': 499,
#  'Ray Liotta': 500,
#  'Christopher Lloyd': 8469634,
#  'Emily Lloyd': 8984320,
#  'Amy Locane': 503,
#  'Nia Long': 504,
#  'Julia Louis-Dreyfus': 505,
#  'Rob Lowe': 8847118,
#  'Carey Lowell': 507,
#  'Bela Lugosi': 508,
#  'Andie MacDowell': 509,
#  'Shirley MacLaine': 510,
#  'Elle Macpherson': 511,
#  'William H. Macy': 512,
#  'Michael Madsen': 9871654,
#  'Virginia Madsen': 514,
#  'Lee Majors': 9324097,
#  'Terrence Malick': 516,
#  'John Malkovich': 517,
#  'David Mamet': 518,
#  'Michael Mann': 10043357,
#  'Sophie Marceau': 520,
#  'Vanessa Marcil': 521,
#  'Julianna Margulies': 522,
#  'Mary Stuart Masterson': 523,
#  'Heather Matarazzo': 524,
#  'Samantha Mathis': 2050498,
#  'Walter Matthau': 526,
#  'Mathilda May': 527,
#  'Debi Mazar': 528,
#  'Andrew McCarthy': 7838915,
#  'Frances McDormand': 530,
#  'Malcolm McDowell': 8768184,
#  'Gates McFadden': 532,
#  'Kelly McGillis': 533,
#  'Rose McGowan': 4587983,
#  'Robert Duncan McNeill': 535,
#  'Steve McQueen': 8175893,
#  'Colm Meaney': 537,
#  'Dina Meyer': 538,
#  'Russ Meyer': 8828637,
#  'Bette Midler': 540,
#  'Penelope Ann Miller': 541,
#  'Sal Mineo': 542,
#  'Carmen Miranda': 8998157,
#  'Helen Mirren': 8626318,
#  'Matthew Modine': 545,
#  'Alfred Molina': 546,
#  'Elizabeth Montgomery': 9926817,
#  'Roger Moore': 8267056,
#  'Kate Mulgrew': 549,
#  'Dermot Mulroney': 550,
#  'Eddie Murphy': 6589422,
#  'Liam Neeson': 552,
#  'Sam Neill': 2061545,
#  'Judd Nelson': 554,
#  'Olivia Newton-John': 555,
#  'Brigitte Nielsen': 556,
#  'Leslie Nielsen': 975773,
#  'Leonard Nimoy': 558,
#  'Nick Nolte': 559,
#  'Peter North': 8522675,
#  'Jeremy Northam': 561,
#  "Chris O'Donnell": 8466185,
#  "Peter O'Toole": 8786571,
#  'Lena Olin': 564,
#  'Julia Ormond': 565,
#  'George Orwell': 6789652,
#  'Frank Oz': 567,
#  'Gwyneth Paltrow': 568,
#  'Alan Parker': 8998807,
#  'Mary-Louise Parker': 570,
#  'Sarah Jessica Parker': 571,
#  'Dolly Parton': 572,
#  'Jason Patric': 573,
#  'Alexandra Paul': 7611020,
#  'Sean Penn': 7274179,
#  'George Peppard': 576,
#  'Anthony Perkins': 9604037,
#  'Ron Perlman': 7725278,
#  'Luke Perry': 4579473,
#  'Joseph L. Mankiewicz': 580,
#  'Joe Pesci': 581,
#  'Wolfgang Petersen': 582,
#  'Amanda Peterson': 8915554,
#  'Robert Picardo': 584,
#  'Jada Pinkett Smith': 1938363,
#  'Donald Pleasence': 586,
#  'Martha Plimpton': 587,
#  'Eve Plumb': 588,
#  'Edgar Allan Poe': 589,
#  'Roman Polanski': 9570053,
#  'Pete Postlethwaite': 591,
#  'Kelly Preston': 592,
#  'Jason Priestley': 8718637,
#  'Victoria Principal': 594,
#  'Jonathan Pryce': 595,
#  'Bill Pullman': 7513634,
#  'Dennis Quaid': 597,
#  'Kathleen Quinlan': 598,
#  'Sam Raimi': 599,
#  'Harold Ramis': 600,
#  'Robert Redford': 8809267,
#  'Vanessa Redgrave': 602,
#  'John C. Reilly': 8395733,
#  'Brad Renfro': 604,
#  'Jean Reno': 680235,
#  'Paul Reubens': 606,
#  'Burt Reynolds': 682032,
#  'Ving Rhames': 608,
#  'Giovanni Ribisi': 1373391,
#  'Ariana Richards': 610,
#  'Denise Richards': 9685700,
#  'Joely Richardson': 612,
#  'Alan Rickman': 7988126,
#  'John Ritter': 614,
#  'Eric Roberts': 9664133,
#  'Tanya Roberts': 7883695,
#  'Isabella Rossellini': 617,
#  'Tim Roth': 7603023,
#  'Mickey Rourke': 619,
#  'Kurt Russell': 4476916,
#  'Theresa Russell': 9340024,
#  'Rene Russo': 9202679,
#  'Laura San Giacomo': 623,
#  'Fred Savage': 1571467,
#  'John Sayles': 8933794,
#  'Greta Scacchi': 626,
#  'Johnathon Schaech': 627,
#  'Claudia Schiffer': 628,
#  'Liev Schreiber': 629,
#  'Ridley Scott': 630,
#  'Jerry Seinfeld': 631,
#  'Tom Selleck': 632,
#  'Peter Sellers': 5235121,
#  'Yahoo Serious': 634,
#  'William Shakespeare': 6372646,
#  'Tupac Shakur': 636,
#  'William Shatner': 637,
#  'Ally Sheedy': 638,
#  'Martin Sheen': 639,
#  'Gary Sinise': 640,
#  'Marina Sirtis': 641,
#  'Tom Skerritt': 642,
#  'Helen Slater': 643,
#  'Anna Nicole Smith': 644,
#  'Jaclyn Smith': 9110136,
#  'Alan Smithee': 9697970,
#  'Wesley Snipes': 647,
#  'Paul Sorvino': 648,
#  'Talisa Soto': 649,
#  'Sissy Spacek': 650,
#  'James Spader': 651,
#  'Brent Spiner': 652,
#  'Terence Stamp': 653,
#  'Eric Stoltz': 654,
#  'Madeleine Stowe': 655,
#  'David Strathairn': 656,
#  'Meryl Streep': 657,
#  'Barbra Streisand': 658,
#  'Tami Stronach': 659,
#  'Donald Sutherland': 7673254,
#  'Kiefer Sutherland': 8420529,
#  'Dominique Swain': 662,
#  'Patrick Swayze': 663,
#  'D.B. Sweeney': 664,
#  'Lili Taylor': 3002164,
#  'David Thewlis': 666,
#  'Emma Thompson': 10002082,
#  'Fred Dalton Thompson': 668,
#  'Lea Thompson': 4855526,
#  'Billy Bob Thornton': 670,
#  'Meg Tilly': 671,
#  'Marisa Tomei': 672,
#  'Tamlyn Tomita': 673,
#  'Jeanne Tripplehorn': 674,
#  'Chris Tucker': 9857402,
#  'Robin Tunney': 676,
#  'Kathleen Turner': 7365084,
#  'Deborah Kara Unger': 678,
#  'Casper Van Dien': 679,
#  'Vince Vaughn': 8111095,
#  'Paul Verhoeven': 5983667,
#  'Gore Vidal': 682,
#  'Nana Visitor': 683,
#  'Jon Voight': 684,
#  'Christopher Walken': 685,
#  'J.T. Walsh': 686,
#  'Sela Ward': 687,
#  'Julie Warner': 7039809,
#  'Lesley Ann Warren': 689,
#  'John Waters': 9481898,
#  'Teri Weigel': 6546233,
#  'Peter Weller': 2487755,
#  'Wim Wenders': 693,
#  'Joanne Whalley': 694,
#  'Wil Wheaton': 695,
#  'Billy Wilder': 2156220,
#  'Gene Wilder': 697,
#  'Michael Wincott': 698,
#  'Debra Winger': 699,
#  'Kate Winslet': 700,
#  'Reese Witherspoon': 701,
#  'BD Wong': 702,
#  'Elijah Wood': 8966710,
#  'Robin Wright': 7996558,
#  'Michelle Yeoh': 705,
#  'Sean Young': 9525141,
#  'Billy Zane': 1843833,
#  'Robert Zemeckis': 708,
#  'David Raksin': 709,
#  'Rick Baker': 9370015,
#  'Steve Cohen': 9677969,
#  'Joel Oliansky': 712,
#  'Willie Aames': 713,
#  'Caroline Aaron': 714,
#  'Paula Abdul': 715,
#  'Kareem Abdul-Jabbar': 3751413,
#  'Ian Abercrombie': 717,
#  'F. Murray Abraham': 718,
#  'Jim Abrahams': 719,
#  'Victoria Abril': 720,
#  'Joss Ackland': 721,
#  'Deborah Adair': 9797428,
#  'Brooke Adams': 10062936,
#  'Joey Lauren Adams': 724,
#  'Maud Adams': 725,
#  'Percy Adlon': 726,
#  'Mario Adorf': 727,
#  'Casey Affleck': 728,
#  'John Agar': 729,
#  'Brian Aherne': 3367396,
#  'Danny Aiello': 2195221,
#  'Anouk Aimée': 732,
#  'Eddie Albert': 9406951,
#  'Brian Aldiss': 734,
#  'Robert Aldrich': 8692843,
#  'Jane Alexander': 9532252,
#  'Muhammad Ali': 10059986,
#  'Debbie Allen': 9474906,
#  'Irwin Allen': 8695086,
#  'Tim Allen': 9863957,
#  'June Allyson': 741,
#  'Néstor Almendros': 742,
#  'Maria Conchita Alonso': 743,
#  'Carol Alt': 744,
#  'Trini Alvarado': 745,
#  'Don Ameche': 746,
#  'Leon Ames': 747,
#  'Mädchen Amick': 748,
#  'Jon Amiel': 749,
#  'Suzy Amis': 750,
#  'Judith Anderson': 10011479,
#  'Juliet Anderson': 1390748,
#  'Kevin Anderson': 9954052,
#  'Lindsay Anderson': 9803054,
#  'Loni Anderson': 755,
#  'Melissa Sue Anderson': 756,
#  'Melody Anderson': 5766721,
#  'Paul Thomas Anderson': 758,
#  'Richard Dean Anderson': 759,
#  'Bibi Andersson': 760,
#  'Anthony Andrews': 9617337,
#  'Dana Andrews': 7870400,
#  'André the Giant': 763,
#  'Pier Angeli': 764,
#  'Theodoros Angelopoulos': 765,
#  'Jean-Hugues Anglade': 766,
#  'Francesca Annis': 767,
#  'Susan Anspach': 768,
#  'David Anspaugh': 9703083,
#  'Lysette Anthony': 770,
#  'Susan Anton': 771,
#  'Laura Antonelli': 9355646,
#  'Michelangelo Antonioni': 773,
#  'Christina Applegate': 774,
#  'Michael Apted': 775,
#  'Gregg Araki': 776,
#  'Alfonso Arau': 777,
#  "Roscoe 'Fatty' Arbuckle": 778,
#  'Denys Arcand': 779,
#  'Eve Arden': 780,
#  'Asia Argento': 781,
#  'Dario Argento': 782,
#  'Pedro Armendáriz': 783,
#  'Alison Armitage': 784,
#  'George Armitage': 785,
#  'Bess Armstrong': 786,
#  'Gillian Armstrong': 787,
#  'Desi Arnaz': 788,
#  'James Arness': 7334833,
#  'Jack Arnold': 8652699,
#  'Tom Arnold': 9322676,
#  'Alexis Arquette': 792,
#  'Lewis Arquette': 793,
#  'Jean Arthur': 8979119,
#  'Dana Ashbrook': 795,
#  'Hal Ashby': 796,
#  'Linden Ashby': 797,
#  'Edward Asner': 798,
#  'Armand Assante': 799,
#  'Olivier Assayas': 800,
#  'Mary Astor': 801,
#  'Christopher Atkins': 8823364,
#  'Stéphane Audran': 803,
#  'Claudine Auger': 804,
#  'Bille August': 805,
#  'Jane Austen': 40558,
#  'Paul Auster': 807,
#  'Daniel Auteuil': 808,
#  'Gene Autry': 8555656,
#  'Frankie Avalon': 810,
#  'Roger Avary': 811,
#  'Tex Avery': 9786935,
#  'John G. Avildsen': 813,
#  'Mili Avital': 814,
#  'Jon Avnet': 815,
#  'Lew Ayres': 816,
#  'Shabana Azmi': 817,
#  'Barbara Bach': 4663465,
#  'Burt Bacharach': 819,
#  'Amitabh Bachchan': 820,
#  'Jim Backus': 7953103,
#  'Angelo Badalamenti': 822,
#  'John Badham': 823,
#  'Mary Badham': 824,
#  'Jane Badler': 825,
#  'Maxine Bahns': 826,
#  'Barbara Bain': 9626254,
#  'Stuart Baird': 828,
#  'Oksana Baiul': 829,
#  'Diane Baker': 8199933,
#  'Joe Don Baker': 831,
#  'Kathy Baker': 3915228,
#  'Ralph Bakshi': 833,
#  'Scott Bakula': 834,
#  'Bob Balaban': 835,
#  'Daniel Baldwin': 10052524,
#  'Ina Balin': 837,
#  'Lucille Ball': 838,
#  'Michael Ballhaus': 2479721,
#  'Martin Balsam': 840,
#  'Anne Bancroft': 49411,
#  'Tamasaburô Bandô': 842,
#  'Tallulah Bankhead': 843,
#  'Ian Bannen': 844,
#  'Theda Bara': 845,
#  'Olivia Barash': 846,
#  'Javier Bardem': 847,
#  'Clive Barker': 9641353,
#  'Lex Barker': 4481798,
#  'Jean-Marc Barr': 5770853,
#  'Bruno Barreto': 1344519,
#  'Majel Barrett': 852,
#  'Raymond J. Barry': 853,
#  'Ethel Barrymore': 854,
#  'John Drew Barrymore': 855,
#  'John Barrymore': 6696642,
#  'Lionel Barrymore': 857,
#  'Paul Bartel': 5080997,
#  'Freddie Bartholomew': 859,
#  'Robin Bartlett': 860,
#  'Billy Barty': 861,
#  'Mikhail Baryshnikov': 862,
#  'Richard Basehart': 863,
#  'Saul Bass': 864,
#  'Jason Bateman': 1823264,
#  'Justine Bateman': 8740893,
#  'Alan Bates': 9256130,
#  'Kathy Bates': 7089559,
#  'Randall Batinkoff': 869,
#  'Patrick Bauchau': 870,
#  'Belinda Bauer': 6256857,
#  'Steven Bauer': 872,
#  'L. Frank Baum': 873,
#  'Noah Baumbach': 874,
#  'Lamberto Bava': 875,
#  'Mario Bava': 876,
#  'Anne Baxter': 8770927,
#  'Meredith Baxter': 878,
#  'Michael Bay': 8958366,
#  'Nathalie Baye': 880,
#  'Stephanie Beacham': 881,
#  'Jennifer Beals': 882,
#  'Ned Beatty': 883,
#  'Warren Beatty': 5929572,
#  'Harold Becker': 885,
#  'Meret Becker': 886,
#  'Bonnie Bedelia': 887,
#  'Noah Beery Jr.': 888,
#  'Wallace Beery': 889,
#  'Jason Beghe': 890,
#  'Ed Begley Jr.': 891,
#  'Jean-Jacques Beineix': 892,
#  'Barbara Bel Geddes': 893,
#  'Harry Belafonte': 894,
#  'Ralph Bellamy': 895,
#  'Kathleen Beller': 896,
#  'Monica Bellucci': 897,
#  'Pamela Bellwood': 898,
#  'Jean-Paul Belmondo': 899,
#  'Jim Belushi': 900,
#  'Brian Benben': 901,
#  'William Bendix': 902,
#  'Roberto Benigni': 903,
#  'Annette Bening': 904,
#  'Richard Benjamin': 9393528,
#  'David Bennent': 906,
#  'Constance Bennett': 68599,
#  'Joan Bennett': 8338121,
#  'Nigel Bennett': 9853313,
#  'Jack Benny': 910,
#  'Robby Benson': 911,
#  'Robert Benton': 8510890,
#  'Bruce Beresford': 913,
#  'Peter Berg': 8462461,
#  'Polly Bergen': 915,
#  'Helmut Berger': 8261118,
#  'Senta Berger': 8700278,
#  'Patrick Bergin': 918,
#  'Andrew Bergman': 8685135,
#  'Sandahl Bergman': 920,
#  'Busby Berkeley': 921,
#  'Elizabeth Berkley': 922,
#  'Steven Berkoff': 923,
#  'Milton Berle': 924,
#  'Irving Berlin': 72319,
#  'Sandra Bernhard': 6984779,
#  'Corbin Bernsen': 927,
#  'Elmer Bernstein': 928,
#  'Elizabeth Berridge': 9650192,
#  'Halle Berry': 930,
#  'Valerie Bertinelli': 931,
#  'Bernardo Bertolucci': 932,
#  'Bibi Besch': 933,
#  'Martine Beswick': 934,
#  'Richard Beymer': 935,
#  'Daniela Bianchi': 4831907,
#  'Adrian Biddle': 937,
#  'Bigas Luna': 938,
#  'Kathryn Bigelow': 939,
#  'Theodore Bikel': 940,
#  'Traci Bingham': 941,
#  'Antonia Bird': 942,
#  'Jane Birkin': 943,
#  'Whit Bissell': 944,
#  'Karen Black': 8239358,
#  'Shane Black': 7812242,
#  'Cate Blanchett': 947,
#  'Brenda Blethyn': 948,
#  'Joan Blondell': 949,
#  'Hart Bochner': 950,
#  'Peter Bogdanovich': 951,
#  'Jon Bon Jovi': 1637957,
#  'Ward Bond': 953,
#  'Lisa Bonet': 954,
#  'Jan de Bont': 955,
#  'John Boorman': 956,
#  'Powers Boothe': 957,
#  'Barry Bostwick': 958,
#  'Timothy Bottoms': 959,
#  'Carole Bouquet': 960,
#  'Stephen Boyd': 9556867,
#  'Charles Boyer': 6459978,
#  'Danny Boyle': 963,
#  'Lorraine Bracco': 964,
#  'Eric Braeden': 965,
#  'Sônia Braga': 966,
#  'Lillo Brancato': 967,
#  'Jonathan Brandis': 9883698,
#  'Nicoletta Braschi': 969,
#  'Tinto Brass': 970,
#  'Benjamin Bratt': 9770008,
#  'Walter Brennan': 972,
#  'Robert Bresson': 7561920,
#  'Martin Brest': 974,
#  'Beau Bridges': 3933667,
#  'Lloyd Bridges': 976,
#  'Wilford Brimley': 8370810,
#  'Jim Broadbent': 978,
#  'James Brolin': 979,
#  'Josh Brolin': 980,
#  'Albert Brooks': 3133248,
#  'Avery Brooks': 9926405,
#  'James L. Brooks': 983,
#  'Bryan Brown': 9830130,
#  'Jim Brown': 9988617,
#  'Jerry Bruckheimer': 986,
#  'Yul Brynner': 8435395,
#  'Betty Buckley': 988,
#  'Geneviève Bujold': 989,
#  'Billie Burke': 990,
#  'Carol Burnett': 991,
#  'Raymond Burr': 992,
#  'Ellen Burstyn': 993,
#  'LeVar Burton': 994,
#  'Gary Busey': 2120670,
#  'Jake Busey': 996,
#  'Red Buttons': 997,
#  'Tom Byron': 5331335,
#  'James Caan': 9726229,
#  'Dean Cain': 8725441,
#  ...}

# %%
index_by_name['Arnold Schwarzenegger']
# Out:
# 215

# %%
import bisect

sorted_fruits = ['apple', 'banana', 'orange', 'plum']
bisect.bisect_left(sorted_fruits, 'bananas')
# Out:
# 2

# %%
# bisect search
def find_index(elements, value):
    index = bisect.bisect_left(elements, value)
    if index < len(elements) and elements[index] == value:
        return index

# %%
sorted_names = load_names('sorted_names.txt')
# Out:
# Loading names...ok

# %%
i = find_index(sorted_names, 'Arnold Schwarzenegger')
i
# Out:
# 804432

# %%
# class for using bisect
class SearchBy:
    def __init__(self, key, elements):
        self.elements_by_key = sorted([(key(x), x) for x in elements])
        self.keys = [x[0] for x in self.elements_by_key]
        
    def find(self, value):
        index = bisect.bisect_left(self.keys, value)
        if index < len(self.keys) and self.keys[index] == value:
            return self.elements_by_key[index][1]

# %%
arnold = SearchBy(names)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-4d6731536a38> in <module>
# ----> 1 arnold = SearchBy(names)
#
# TypeError: __init__() missing 1 required positional argument: 'elements'

# %% [markdown]
# Binary iteratively

# %%
def identity(element):
    return element

# %%
def find_index(elements, value, key=identity):
    left, right = 0, len(elements) - 1
    
    while left <= right:
        middle = (left + right) // 2
        middle_element = key(elements[middle])

        if middle_element == value:
            return middle

        if middle_element < value:
            left = middle + 1
        elif middle_element > value:
            right = middle - 1

# %%
def contains(elements, value, key=identity):
    return find_index(elements, value, key) is not None

# %%
def find(elements, value, key=identity):
    index = find_index(elements, value, key)
    return None if index is None else elements[index]
